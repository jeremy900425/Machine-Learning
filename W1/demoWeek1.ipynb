# %% [markdown]
# # Introduction to Machine Learning

# %% [markdown]
# ### An example for sample codes shared on NCCU Google Workspace
# #### Note: must log into your @g.nccu.edu.tw account to access the files

# %%
print("ss")
import pandas as pd
# Out:
# ss
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/chouchenyu/政大資科/機器學習概論/demoWeek1.ipynb 儲存格 3 line 2
#       <a href='vscode-notebook-cell:/Users/chouchenyu/%E6%94%BF%E5%A4%A7%E8%B3%87%E7%A7%91/%E6%A9%9F%E5%99%A8%E5%AD%B8%E7%BF%92%E6%A6%82%E8%AB%96/demoWeek1.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> print("ss")
# ----> <a href='vscode-notebook-cell:/Users/chouchenyu/%E6%94%BF%E5%A4%A7%E8%B3%87%E7%A7%91/%E6%A9%9F%E5%99%A8%E5%AD%B8%E7%BF%92%E6%A6%82%E8%AB%96/demoWeek1.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
data_file = "./demo.csv"

# %%
df = pd.read_csv(data_file)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-49e07b6682ac> in <cell line: 1>()
# ----> 1 df = pd.read_csv(data_file)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
df

# %%
df.describe()

# %% [markdown]
# #### useful for Google Colab (Colaboratory)

# %%
data_file = "./demo_google_colab.csv"
df = pd.read_csv(data_file)
df.describe()
# Out:
#              id         f1         f2         f3      value
# count  20.00000  20.000000  20.000000  20.000000  20.000000
# mean   10.50000  16.450000  15.350000  14.300000   0.050000
# std     5.91608   8.394704   7.788487   9.136969  19.824161
# min     1.00000   2.000000   2.000000   1.000000 -37.000000
# 25%     5.75000  10.750000  10.250000   7.750000 -14.250000
# 50%    10.50000  16.000000  15.000000  14.500000   2.500000
# 75%    15.25000  24.250000  23.000000  23.000000  15.250000
# max    20.00000  28.000000  28.000000  29.000000  30.000000
